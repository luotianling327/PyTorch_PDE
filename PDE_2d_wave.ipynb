# %%
# !pip install nangs
# !pip install torch


# 2-dimensional wave equation
# u_tt = c^2 * (u_xx + u_yy)
# u(0,y,t) = u(a,y,t) = 0   0<=y<=b, t>=0
# u(x,0,t) = u(x,b,t) = 0   0<=x<=a, t>=0
# u(x,y,0) = f(x,y)
# u_t(x,t,0) = g(x,y)
import numpy as np
import matplotlib.pyplot as plt
import nangs
import torch
from nangs import *
device = "cuda" if torch.cuda.is_available() else "cpu"

class Wave(PDE):
    def computePDELoss(self, inputs, outputs):
        x, y, t=inputs[:,0], inputs[:,1], inputs[:,2]
        u = outputs[:,0]
        
        #compute gradients
        grads=self.computeGrads(outputs, inputs)
        
        #compute loss
        u_x, u_y, u_t=grads[:, 0], grads[:, 1], grads[:, 2]
        
        grads2=self.computeGrads(u_x, inputs)
        u_xx=grads2[:, 0]
        
        grads2=self.computeGrads(u_y, inputs)
        u_yy=grads2[:, 1]
        
        grads2=self.computeGrads(u_t, inputs)
        u_tt=grads2[:, 2]
        
        # c = 1, a = 1, b = 1
        return {'pde': u_tt-u_xx-u_yy}
    
pde=Wave(inputs=('x', 'y', 't'), outputs='u')
# Out:
# Collecting nangs
#   Downloading https://files.pythonhosted.org/packages/4c/cd/7eeca93e6088a85d18ff99897743aaf429c94c12049e56f2a1e8b2091656/nangs-0.1.2-py3-none-any.whl
# Installing collected packages: nangs
# Successfully installed nangs-0.1.2
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (1.6.0+cu101)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch) (1.18.5)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch) (0.16.0)

# %%
# a = b = 1

x = np.linspace(0,1,20)
y = np.linspace(0,1,20)
t = np.linspace(0,1,30)

mesh = Mesh({'x': x, 'y': y, 't': t}, device=device)
pde.set_mesh(mesh)

# %%
# boundary conditions

x0 = np.array([0., 1.])
y0 = np.array([0., 1.])
t0 = np.array([0])

_x, _y, _t = np.meshgrid(x, y, t0)
u0 = np.sin(np.pi*_x)*np.sin(np.pi*_y)
initial_condition=Dirichlet({'x': x, 'y': y, 't': t0}, {'u': u0.reshape(-1)}, 
                            device=device, name='initial')
pde.add_boco(initial_condition)

_x, _y, _t = np.meshgrid(x0, y, t)
u1 = _x*_y*_t*0
boco_x=Dirichlet({'x': x0, 'y': y, 't': t}, {'u': u1.reshape(-1)}, device=device, 
                 name='boco_x')
pde.add_boco(boco_x)

_x, _y, _t = np.meshgrid(x, y0, t)
u1 = _x*_y*_t*0
boco_y=Dirichlet({'x': x, 'y': y0, 't': t}, {'u': u1.reshape(-1)}, device=device, 
                 name='boco_y')
pde.add_boco(boco_y)

# %%
PI=3.14159265
SQRT_2=1.41421356

class MyNeumann(Neumann):
    def computeBocoLoss(self, inputs, outputs):
        u_t=self.computeGrads(outputs, inputs)[:,2]
        x,y=inputs[:, 0], inputs[:, 1]
        return {'grad_t': u_t-torch.sin(PI*x)*torch.sin(PI*y)*SQRT_2*PI}
    
boco=MyNeumann({'x': x, 'y': y, 't': t0}, name='neumann', device=device)
pde.add_boco(boco)

# %%
torch.cuda.is_available()
device
# Out:
# 'cuda'

# %%
BATCH_SIZE = 512
LR = 5e-4
EPOCHS = 1000
NUM_LAYERS = 8
NUM_HIDDEN = 256

mlp = MLP(len(pde.inputs), len(pde.outputs), NUM_LAYERS, NUM_HIDDEN).to(device)
optimizer = torch.optim.Adam(mlp.parameters())
scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr=LR, 
                                                pct_start=0.1, total_steps=EPOCHS)

pde.compile(mlp, optimizer, scheduler)
# %time hist = pde.solve(EPOCHS, BATCH_SIZE)
# Out:
# Epoch 1/1000  | lr 2e-05 | initial 0.21903 | boco_x 0.00146 | boco_y 0.00146 | neumann_grad_t 4.34783 | pde 0.0<p>Epoch 2/1000  | lr 2e-05 | initial 0.19776 | boco_x 0.01368 | boco_y 0.01364 | neumann_grad_t 4.01516 | pde 9e-05<p>Epoch 3/1000  | lr 2e-05 | initial 0.26518 | boco_x 0.0372 | boco_y 0.03698 | neumann_grad_t 3.30086 | pde 0.00278<p>Epoch 4/1000  | lr 2e-05 | initial 0.546 | boco_x 0.08246 | boco_y 0.0823 | neumann_grad_t 2.37887 | pde 0.0217<p>Epoch 5/1000  | lr 2e-05 | initial 0.53968 | boco_x 0.07637 | boco_y 0.07658 | neumann_grad_t 2.3701 | pde 0.02132<p>Epoch 6/1000  | lr 2e-05 | initial 0.47502 | boco_x 0.06702 | boco_y 0.06721 | neumann_grad_t 2.46773 | pde 0.01731<p>Epoch 7/1000  | lr 2e-05 | initial 0.53294 | boco_x 0.07397 | boco_y 0.07395 | neumann_grad_t 2.33221 | pde 0.024<p>Epoch 8/1000  | lr 3e-05 | initial 0.50534 | boco_x 0.06915 | boco_y 0.06837 | neumann_grad_t 2.36182 | pde 0.02437<p>Epoch 9/1000  | lr 3e-05 | initial 0.51333 | boco_x 0.06872 | boco_y 0.06853 | neumann_grad_t 2.3115 | pde 0.02898<p>Epoch 10/1000  | lr 3e-05 | initial 0.50507 | boco_x 0.06511 | boco_y 0.06473 | neumann_grad_t 2.28563 | pde 0.0313<p>Epoch 11/1000  | lr 3e-05 | initial 0.49664 | boco_x 0.0614 | boco_y 0.0607 | neumann_grad_t 2.22808 | pde 0.03152<p>Epoch 12/1000  | lr 3e-05 | initial 0.45919 | boco_x 0.0521 | boco_y 0.04997 | neumann_grad_t 2.13487 | pde 0.02512<p>Epoch 13/1000  | lr 4e-05 | initial 0.33674 | boco_x 0.03161 | boco_y 0.02556 | neumann_grad_t 1.92633 | pde 0.1159<p>Epoch 14/1000  | lr 4e-05 | initial 0.2215 | boco_x 0.03109 | boco_y 0.02062 | neumann_grad_t 1.74651 | pde 0.13511<p>Epoch 15/1000  | lr 4e-05 | initial 0.19468 | boco_x 0.03656 | boco_y 0.02415 | neumann_grad_t 1.68406 | pde 0.03661<p>Epoch 16/1000  | lr 5e-05 | initial 0.17984 | boco_x 0.04096 | boco_y 0.02956 | neumann_grad_t 1.6266 | pde 0.02917<p>Epoch 17/1000  | lr 5e-05 | initial 0.18957 | boco_x 0.03844 | boco_y 0.02914 | neumann_grad_t 1.58487 | pde 0.0249<p>Epoch 18/1000  | lr 5e-05 | initial 0.18813 | boco_x 0.04105 | boco_y 0.03341 | neumann_grad_t 1.52178 | pde 0.02324<p>Epoch 19/1000  | lr 6e-05 | initial 0.19323 | boco_x 0.04155 | boco_y 0.03599 | neumann_grad_t 1.45127 | pde 0.0206<p>Epoch 20/1000  | lr 6e-05 | initial 0.19214 | boco_x 0.04432 | boco_y 0.04029 | neumann_grad_t 1.35273 | pde 0.01797<p>Epoch 21/1000  | lr 7e-05 | initial 0.1936 | boco_x 0.04619 | boco_y 0.04422 | neumann_grad_t 1.21012 | pde 0.01478<p>Epoch 22/1000  | lr 7e-05 | initial 0.19243 | boco_x 0.04868 | boco_y 0.04901 | neumann_grad_t 0.97531 | pde 0.01736<p>Epoch 23/1000  | lr 8e-05 | initial 0.19257 | boco_x 0.05013 | boco_y 0.04986 | neumann_grad_t 0.63491 | pde 0.04344<p>Epoch 24/1000  | lr 8e-05 | initial 0.18783 | boco_x 0.04714 | boco_y 0.04427 | neumann_grad_t 0.33687 | pde 0.07702<p>Epoch 25/1000  | lr 9e-05 | initial 0.18371 | boco_x 0.03877 | boco_y 0.04714 | neumann_grad_t 0.21935 | pde 0.06786<p>Epoch 26/1000  | lr 9e-05 | initial 0.17665 | boco_x 0.03366 | boco_y 0.04634 | neumann_grad_t 0.18064 | pde 0.05533<p>Epoch 27/1000  | lr 0.0001 | initial 0.16899 | boco_x 0.03003 | boco_y 0.04588 | neumann_grad_t 0.16107 | pde 0.05071<p>Epoch 28/1000  | lr 0.0001 | initial 0.16175 | boco_x 0.02734 | boco_y 0.0459 | neumann_grad_t 0.14414 | pde 0.04353<p>Epoch 29/1000  | lr 0.00011 | initial 0.15331 | boco_x 0.02484 | boco_y 0.04561 | neumann_grad_t 0.12526 | pde 0.03677<p>Epoch 30/1000  | lr 0.00011 | initial 0.14607 | boco_x 0.02249 | boco_y 0.04526 | neumann_grad_t 0.10313 | pde 0.0344<p>Epoch 31/1000  | lr 0.00012 | initial 0.13825 | boco_x 0.02073 | boco_y 0.04284 | neumann_grad_t 0.0813 | pde 0.03353<p>Epoch 32/1000  | lr 0.00013 | initial 0.12727 | boco_x 0.01924 | boco_y 0.03913 | neumann_grad_t 0.05833 | pde 0.02963<p>Epoch 33/1000  | lr 0.00013 | initial 0.1163 | boco_x 0.01796 | boco_y 0.03424 | neumann_grad_t 0.0432 | pde 0.02901<p>Epoch 34/1000  | lr 0.00014 | initial 0.10803 | boco_x 0.0187 | boco_y 0.03195 | neumann_grad_t 0.04 ...
# CPU times: user 23min 48s, sys: 19.3 s, total: 24min 7s
# Wall time: 24min 56s

# %%
# evaluate
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

x = np.linspace(0,1,100)
y = np.linspace(0,1,100)
t = np.array([0,0.2,0.4,0.6,0.8,1])

for t1 in t:

    eval_mesh=Mesh({'x': x,'y': y, 't':t1}, device=device)

    u=pde.eval(eval_mesh)
    u=u.cpu().numpy()
    
    _x, _y=np.meshgrid(x,y)
    u0=np.sin(np.pi*_x)*np.sin(np.pi*_y)*(np.cos(np.sqrt(2)*np.pi*t1)+
                                          np.sin(np.sqrt(2)*np.pi*t1))

    fig=plt.figure(figsize=(15, 5))
    ax1=fig.add_subplot(1,2,1,projection='3d')
    ax2=fig.add_subplot(1,2,2,projection='3d')
    ax1.plot_surface(_x, _y, u0.reshape((len(_y),len(_x))), cmap=cm.coolwarm, 
                     linewidth=0, antialiased=False)
    ax1.title.set_text('exact, t = %f' % t1)
    ax2.plot_surface(_x, _y, u.reshape((len(_y),len(_x))), cmap=cm.coolwarm, 
                     linewidth=0, antialiased=False)
    ax2.title.set_text('predicted, t = %f' % t1)
    plt.show()
    print("L2 error: ", np.sqrt(sum((u0.ravel()-u.ravel())**2))
      /np.sqrt(sum(u0.ravel()**2))*100,"%")
# Out:
# L2 error:  0.27511724903981094 %
# L2 error:  0.15982475501302934 %
# L2 error:  0.24049614630902552 %
# L2 error:  0.8943182924512235 %
# L2 error:  0.3220130447208595 %
# L2 error:  0.4596320187416574 %

# %%
for t1 in t:

    eval_mesh=Mesh({'x': x,'y': y, 't':t1}, device=device)

    u=pde.eval(eval_mesh)
    u=u.cpu().numpy()
    
    _x, _y=np.meshgrid(x,y)
    u0=np.sin(np.pi*_x)*np.sin(np.pi*_y)*(np.cos(np.sqrt(2)*np.pi*t1)+
                                          np.sin(np.sqrt(2)*np.pi*t1))

    plt.imshow(u0.reshape(len(y),len(x)), vmin=u0.min(), vmax=u0.max(), 
               origin='lower',
               extent=[x.min(), x.max(), y.min(), y.max()])
    plt.colorbar()
    plt.title('exact, t = %f' % t1)
    plt.show()

    plt.imshow(u.reshape((len(y),len(x))), vmin=u.min(), vmax=u.max(), 
               origin='lower',
               extent=[x.min(), x.max(), y.min(), y.max()])
    plt.colorbar()
    plt.title('predicted, t = %f' % t1)
    plt.show()
