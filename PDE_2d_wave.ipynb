# %%
# 2-dimensional wave equation
# u_tt = c^2 * (u_xx + u_yy)
# u(0,y,t) = u(a,y,t) = 0   0<=y<=b, t>=0
# u(x,0,t) = u(x,b,t) = 0   0<=x<=a, t>=0
# u(x,y,0) = f(x,y)
# u_t(x,t,0) = g(x,y)
import numpy as np
import matplotlib.pyplot as plt
import nangs
import torch
from nangs import *
device = "cuda" if torch.cuda.is_available() else "cpu"

class Wave(PDE):
    def computePDELoss(self, inputs, outputs):
        x, y, t=inputs[:,0], inputs[:,1], inputs[:,2]
        u = outputs[:,0]
        
        #compute gradients
        grads=self.computeGrads(outputs, inputs)
        
        #compute loss
        u_x, u_y, u_t=grads[:, 0], grads[:, 1], grads[:, 2]
        
        grads2=self.computeGrads(u_x, inputs)
        u_xx=grads2[:, 0]
        
        grads2=self.computeGrads(u_y, inputs)
        u_yy=grads2[:, 1]
        
        grads2=self.computeGrads(u_t, inputs)
        u_tt=grads2[:, 2]
        
        # c = 1, a = 1, b = 1
        return {'pde': u_tt-u_xx-u_yy}
    
pde=Wave(inputs=('x', 'y', 't'), outputs='u')

# %%
# a = b = 1

x = np.linspace(0,1,20)
y = np.linspace(0,1,20)
t = np.linspace(0,1,30)

mesh = Mesh({'x': x, 'y': y, 't': t}, device=device)
pde.set_mesh(mesh)

# %%
# boundary conditions

x0 = np.array([0., 1.])
y0 = np.array([0., 1.])
t0 = np.array([0])

_x, _y, _t = np.meshgrid(x, y, t0)
u0 = np.sin(np.pi*_x)*np.sin(np.pi*_y)
initial_condition=Dirichlet({'x': x, 'y': y, 't': t0}, {'u': u0.reshape(-1)}, 
                            device=device, name='initial')
pde.add_boco(initial_condition)

_x, _y, _t = np.meshgrid(x0, y, t)
u1 = _x*_y*_t*0
boco_x=Dirichlet({'x': x0, 'y': y, 't': t}, {'u': u1.reshape(-1)}, device=device, 
                 name='boco_x')
pde.add_boco(boco_x)

_x, _y, _t = np.meshgrid(x, y0, t)
u1 = _x*_y*_t*0
boco_y=Dirichlet({'x': x, 'y': y0, 't': t}, {'u': u1.reshape(-1)}, device=device, 
                 name='boco_y')
pde.add_boco(boco_y)

# %%
PI=3.14159265
SQRT_2=1.41421356

class MyNeumann(Neumann):
    def computeBocoLoss(self, inputs, outputs):
        u_t=self.computeGrads(outputs, inputs)[:,2]
        x,y=inputs[:, 0], inputs[:, 1]
        return {'grad_t': u_t-torch.sin(PI*x)*torch.sin(PI*y)*SQRT_2*PI}
    
boco=MyNeumann({'x': x, 'y': y, 't': t0}, name='neumann', device=device)
pde.add_boco(boco)

# %%
BATCH_SIZE = 512
LR = 5e-4
EPOCHS = 1000
NUM_LAYERS = 8
NUM_HIDDEN = 256

mlp = MLP(len(pde.inputs), len(pde.outputs), NUM_LAYERS, NUM_HIDDEN).to(device)
optimizer = torch.optim.Adam(mlp.parameters())
scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr=LR, 
                                                pct_start=0.1, total_steps=EPOCHS)

pde.compile(mlp, optimizer, scheduler)
# %time hist = pde.solve(EPOCHS, BATCH_SIZE)
# Out:
# Epoch 1/1000  | lr 2e-05 | initial 0.19657 | boco_x 0.00356 | boco_y 0.00357 | neumann_grad_t 4.35337 | pde 1e-05<p>Epoch 2/1000  | lr 2e-05 | initial 0.20303 | boco_x 0.01176 | boco_y 0.01175 | neumann_grad_t 4.01954 | pde 1e-05<p>Epoch 3/1000  | lr 2e-05 | initial 0.27097 | boco_x 0.03777 | boco_y 0.03779 | neumann_grad_t 3.26429 | pde 0.00063<p>Epoch 4/1000  | lr 2e-05 | initial 0.56914 | boco_x 0.08462 | boco_y 0.08455 | neumann_grad_t 2.33083 | pde 0.00938<p>Epoch 5/1000  | lr 2e-05 | initial 0.54374 | boco_x 0.07829 | boco_y 0.07795 | neumann_grad_t 2.34856 | pde 0.00856<p>Epoch 6/1000  | lr 2e-05 | initial 0.47816 | boco_x 0.0682 | boco_y 0.06867 | neumann_grad_t 2.44568 | pde 0.0068<p>Epoch 7/1000  | lr 2e-05 | initial 0.53927 | boco_x 0.07539 | boco_y 0.07578 | neumann_grad_t 2.30586 | pde 0.01141<p>Epoch 8/1000  | lr 3e-05 | initial 0.5065 | boco_x 0.0697 | boco_y 0.07002 | neumann_grad_t 2.33282 | pde 0.01318<p>Epoch 9/1000  | lr 3e-05 | initial 0.51452 | boco_x 0.06842 | boco_y 0.06913 | neumann_grad_t 2.27698 | pde 0.01916<p>Epoch 10/1000  | lr 3e-05 | initial 0.49912 | boco_x 0.06286 | boco_y 0.06379 | neumann_grad_t 2.24267 | pde 0.02638<p>Epoch 11/1000  | lr 3e-05 | initial 0.47305 | boco_x 0.05319 | boco_y 0.05488 | neumann_grad_t 2.17258 | pde 0.03149<p>Epoch 12/1000  | lr 3e-05 | initial 0.38629 | boco_x 0.0348 | boco_y 0.03787 | neumann_grad_t 2.02325 | pde 0.05759<p>Epoch 13/1000  | lr 4e-05 | initial 0.25251 | boco_x 0.02684 | boco_y 0.03232 | neumann_grad_t 1.79582 | pde 0.11432<p>Epoch 14/1000  | lr 4e-05 | initial 0.21178 | boco_x 0.02906 | boco_y 0.03694 | neumann_grad_t 1.67228 | pde 0.04836<p>Epoch 15/1000  | lr 4e-05 | initial 0.18984 | boco_x 0.03154 | boco_y 0.04062 | neumann_grad_t 1.58133 | pde 0.04464<p>Epoch 16/1000  | lr 5e-05 | initial 0.19523 | boco_x 0.03008 | boco_y 0.03976 | neumann_grad_t 1.52539 | pde 0.03304<p>Epoch 17/1000  | lr 5e-05 | initial 0.19593 | boco_x 0.03494 | boco_y 0.04332 | neumann_grad_t 1.44191 | pde 0.03068<p>Epoch 18/1000  | lr 5e-05 | initial 0.20708 | boco_x 0.03824 | boco_y 0.0456 | neumann_grad_t 1.3473 | pde 0.02461<p>Epoch 19/1000  | lr 6e-05 | initial 0.21298 | boco_x 0.04189 | boco_y 0.04879 | neumann_grad_t 1.23579 | pde 0.01888<p>Epoch 20/1000  | lr 6e-05 | initial 0.22109 | boco_x 0.04593 | boco_y 0.05146 | neumann_grad_t 1.09251 | pde 0.01572<p>Epoch 21/1000  | lr 7e-05 | initial 0.22961 | boco_x 0.05053 | boco_y 0.05301 | neumann_grad_t 0.91217 | pde 0.02584<p>Epoch 22/1000  | lr 7e-05 | initial 0.22899 | boco_x 0.05294 | boco_y 0.05395 | neumann_grad_t 0.72368 | pde 0.04348<p>Epoch 23/1000  | lr 8e-05 | initial 0.21708 | boco_x 0.05078 | boco_y 0.05233 | neumann_grad_t 0.55058 | pde 0.04988<p>Epoch 24/1000  | lr 8e-05 | initial 0.1932 | boco_x 0.04603 | boco_y 0.04661 | neumann_grad_t 0.3648 | pde 0.06588<p>Epoch 25/1000  | lr 9e-05 | initial 0.16822 | boco_x 0.03738 | boco_y 0.03552 | neumann_grad_t 0.19578 | pde 0.09198<p>Epoch 26/1000  | lr 9e-05 | initial 0.15147 | boco_x 0.03168 | boco_y 0.02726 | neumann_grad_t 0.11402 | pde 0.09041<p>Epoch 27/1000  | lr 0.0001 | initial 0.13925 | boco_x 0.03086 | boco_y 0.02414 | neumann_grad_t 0.08943 | pde 0.06644<p>Epoch 28/1000  | lr 0.0001 | initial 0.13043 | boco_x 0.02972 | boco_y 0.02187 | neumann_grad_t 0.06926 | pde 0.04899<p>Epoch 29/1000  | lr 0.00011 | initial 0.11839 | boco_x 0.02636 | boco_y 0.01983 | neumann_grad_t 0.05202 | pde 0.03682<p>Epoch 30/1000  | lr 0.00011 | initial 0.10052 | boco_x 0.02254 | boco_y 0.01821 | neumann_grad_t 0.04104 | pde 0.03581<p>Epoch 31/1000  | lr 0.00012 | initial 0.0854 | boco_x 0.01997 | boco_y 0.01764 | neumann_grad_t 0.03425 | pde 0.03554<p>Epoch 32/1000  | lr 0.00013 | initial 0.07118 | boco_x 0.0175 | boco_y 0.01601 | neumann_grad_t 0.0262 | pde 0.03553<p>Epoch 33/1000  | lr 0.00013 | initial 0.05752 | boco_x 0.01837 | boco_y 0.01742 | neumann_grad_t 0.03099 | pde 0.03492<p>Epoch 34/1000  | lr 0.00014 | initial 0.04363 | boco_x 0.01315 | boco_y 0.01292 | neum ...
# Wall time: 2h 54min 30s

# %%
# evaluate
from mpl_toolkits.mplot3d import Axes3D

x = np.linspace(0,1,100)
y = np.linspace(0,1,100)
t = np.array([0,0.2,0.4,0.6,0.8,1])

for t1 in t:

    eval_mesh=Mesh({'x': x,'y': y, 't':t1}, device=device)

    u=pde.eval(eval_mesh)
    u=u.cpu().numpy()
    
    _x, _y=np.meshgrid(x,y)
    u0=np.sin(np.pi*_x)*np.sin(np.pi*_y)*(np.cos(np.sqrt(2)*np.pi*t1)+
                                          np.sin(np.sqrt(2)*np.pi*t1))

    fig=plt.figure(figsize=(15, 5))
    ax1=fig.add_subplot(1,2,1,projection='3d')
    ax2=fig.add_subplot(1,2,2,projection='3d')
    ax1.plot_surface(_x, _y, u0.reshape((len(_y),len(_x))), cmap=cm.coolwarm, 
                     linewidth=0, antialiased=False)
    ax1.title.set_text('exact, t = %f' % t1)
    ax2.plot_surface(_x, _y, u.reshape((len(_y),len(_x))), cmap=cm.coolwarm, 
                     linewidth=0, antialiased=False)
    ax2.title.set_text('predicted, t = %f' % t1)
    plt.show()
    print("L2 error: ", np.sqrt(sum((u0.ravel()-u.ravel())**2)))
# Out:
# L2 error:  0.12943405499580327
# L2 error:  0.06827974239204129
# L2 error:  0.1504949602403366
# L2 error:  0.1352916394279079
# L2 error:  0.17854320999687104
# L2 error:  0.2088300086683179

# %%
for t1 in t:

    eval_mesh=Mesh({'x': x,'y': y, 't':t1}, device=device)

    u=pde.eval(eval_mesh)
    u=u.cpu().numpy()
    
    _x, _y=np.meshgrid(x,y)
    u0=np.sin(np.pi*_x)*np.sin(np.pi*_y)*(np.cos(np.sqrt(2)*np.pi*t1)+
                                          np.sin(np.sqrt(2)*np.pi*t1))

    plt.imshow(u0.reshape(len(y),len(x)), vmin=u0.min(), vmax=u0.max(), 
               origin='lower',
               extent=[x.min(), x.max(), y.min(), y.max()])
    plt.colorbar()
    plt.title('exact, t = %f' % t1)
    plt.show()

    plt.imshow(u.reshape((len(y),len(x))), vmin=u.min(), vmax=u.max(), 
               origin='lower',
               extent=[x.min(), x.max(), y.min(), y.max()])
    plt.colorbar()
    plt.title('predicted, t = %f' % t1)
    plt.show()
