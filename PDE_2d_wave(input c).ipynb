# %%
# 2-dimensional wave equation
# u_tt = c^2 * (u_xx + u_yy)
# u(0,y,t) = u(a,y,t) = 0   0<=y<=b, t>=0
# u(x,0,t) = u(x,b,t) = 0   0<=x<=a, t>=0
# u(x,y,0) = f(x,y)
# u_t(x,t,0) = g(x,y)
import cmath
import numpy as np
import matplotlib.pyplot as plt
import nangs
import torch
from nangs import *
device = "cuda" if torch.cuda.is_available() else "cpu"

class Wave(PDE):
    def computePDELoss(self, inputs, outputs):
        x, y, t, c=inputs[:,0], inputs[:,1], inputs[:,2], inputs[:,3]
        u = outputs[:,0]
        
        #compute gradients
        grads=self.computeGrads(outputs, inputs)
        
        #compute loss
        u_x, u_y, u_t=grads[:, 0], grads[:, 1], grads[:, 2]
        
        grads2=self.computeGrads(u_x, inputs)
        u_xx=grads2[:, 0]
        
        grads2=self.computeGrads(u_y, inputs)
        u_yy=grads2[:, 1]
        
        grads2=self.computeGrads(u_t, inputs)
        u_tt=grads2[:, 2]
        
        return {'pde': u_tt-c*c*u_xx-c*c*u_yy}
    
pde=Wave(inputs=('x', 'y', 't', 'c'), outputs='u')

# %%
# a = b = 1

x = np.linspace(0,1,20)
y = np.linspace(0,1,20)
t = np.linspace(0,1,20)
c = np.array([0.2, 0.4, 0.6, 0.8, 1])

mesh = Mesh({'x': x, 'y': y, 't': t, 'c': c}, device=device)
pde.set_mesh(mesh)

# %%
# boundary conditions

x0 = np.array([0., 1.])
y0 = np.array([0., 1.])
t0 = np.array([0])

_x, _y, _t, _c = np.meshgrid(x, y, t0, c)
u0 = np.sin(np.pi*_x)*np.sin(np.pi*_y)
initial_condition=Dirichlet({'x': x, 'y': y, 't': t0, 'c': c}, {'u': u0.reshape(-1)}, 
                            device=device, name='initial')
pde.add_boco(initial_condition)

_x, _y, _t, _c = np.meshgrid(x0, y, t, c)
u1 = _x*_y*_t*_c*0
boco_x=Dirichlet({'x': x0, 'y': y, 't': t, 'c': c}, {'u': u1.reshape(-1)}, device=device, 
                 name='boco_x')
pde.add_boco(boco_x)

_x, _y, _t, _c = np.meshgrid(x, y0, t, c)
u1 = _x*_y*_t*_c*0
boco_y=Dirichlet({'x': x, 'y': y0, 't': t, 'c': c}, {'u': u1.reshape(-1)}, device=device, 
                 name='boco_y')
pde.add_boco(boco_y)

# %%
PI=3.14159265
SQRT_2=1.41421356

class MyNeumann(Neumann):
    def computeBocoLoss(self, inputs, outputs):
        u_t=self.computeGrads(outputs, inputs)[:,2]
        x,y=inputs[:, 0], inputs[:, 1]
        c=inputs[:, 3]
        return {'grad_t': u_t-c*torch.sin(PI*x)*torch.sin(PI*y)*SQRT_2*PI}
    
boco=MyNeumann({'x': x, 'y': y, 't': t0, 'c': c}, name='neumann', device=device)
pde.add_boco(boco)

# %%
BATCH_SIZE = 512
LR = 5e-4
EPOCHS = 1000
NUM_LAYERS = 8
NUM_HIDDEN = 256

mlp = MLP(len(pde.inputs), len(pde.outputs), NUM_LAYERS, NUM_HIDDEN).to(device)
optimizer = torch.optim.Adam(mlp.parameters())
scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr=LR, 
                                                pct_start=0.1, total_steps=EPOCHS)

pde.compile(mlp, optimizer, scheduler)
# %time hist = pde.solve(EPOCHS, BATCH_SIZE)
# Out:
# Epoch 1/1000  | lr 2e-05 | initial 0.21208 | boco_x 0.01571 | boco_y 0.01576 | neumann_grad_t 1.72162 | pde 0.00064<p>Epoch 2/1000  | lr 2e-05 | initial 0.33749 | boco_x 0.04269 | boco_y 0.04277 | neumann_grad_t 1.19677 | pde 0.00871<p>Epoch 3/1000  | lr 2e-05 | initial 0.33444 | boco_x 0.0407 | boco_y 0.04072 | neumann_grad_t 1.17995 | pde 0.01508<p>Epoch 4/1000  | lr 2e-05 | initial 0.32877 | boco_x 0.03808 | boco_y 0.03817 | neumann_grad_t 1.1585 | pde 0.03289<p>Epoch 5/1000  | lr 2e-05 | initial 0.30048 | boco_x 0.02802 | boco_y 0.02835 | neumann_grad_t 1.09138 | pde 0.1629<p>Epoch 6/1000  | lr 2e-05 | initial 0.21636 | boco_x 0.0208 | boco_y 0.02289 | neumann_grad_t 0.85159 | pde 0.42157<p>Epoch 7/1000  | lr 2e-05 | initial 0.18953 | boco_x 0.01888 | boco_y 0.02072 | neumann_grad_t 0.79479 | pde 0.43323<p>Epoch 8/1000  | lr 3e-05 | initial 0.17172 | boco_x 0.01665 | boco_y 0.01821 | neumann_grad_t 0.76346 | pde 0.44268<p>Epoch 9/1000  | lr 3e-05 | initial 0.15029 | boco_x 0.01565 | boco_y 0.01783 | neumann_grad_t 0.72382 | pde 0.39749<p>Epoch 10/1000  | lr 3e-05 | initial 0.13297 | boco_x 0.01758 | boco_y 0.0206 | neumann_grad_t 0.6892 | pde 0.3502<p>Epoch 11/1000  | lr 3e-05 | initial 0.12594 | boco_x 0.02024 | boco_y 0.02303 | neumann_grad_t 0.66418 | pde 0.32586<p>Epoch 12/1000  | lr 3e-05 | initial 0.12101 | boco_x 0.02202 | boco_y 0.02416 | neumann_grad_t 0.64068 | pde 0.31468<p>Epoch 13/1000  | lr 4e-05 | initial 0.11797 | boco_x 0.02438 | boco_y 0.02579 | neumann_grad_t 0.6147 | pde 0.29862<p>Epoch 14/1000  | lr 4e-05 | initial 0.11703 | boco_x 0.02754 | boco_y 0.02844 | neumann_grad_t 0.59115 | pde 0.28976<p>Epoch 15/1000  | lr 4e-05 | initial 0.11318 | boco_x 0.02795 | boco_y 0.02874 | neumann_grad_t 0.56588 | pde 0.28377<p>Epoch 16/1000  | lr 5e-05 | initial 0.11279 | boco_x 0.03125 | boco_y 0.03182 | neumann_grad_t 0.53802 | pde 0.25725<p>Epoch 17/1000  | lr 5e-05 | initial 0.11052 | boco_x 0.03397 | boco_y 0.03425 | neumann_grad_t 0.50243 | pde 0.21437<p>Epoch 18/1000  | lr 5e-05 | initial 0.11192 | boco_x 0.03868 | boco_y 0.03873 | neumann_grad_t 0.47683 | pde 0.16721<p>Epoch 19/1000  | lr 6e-05 | initial 0.10669 | boco_x 0.04165 | boco_y 0.04156 | neumann_grad_t 0.43457 | pde 0.14189<p>Epoch 20/1000  | lr 6e-05 | initial 0.10368 | boco_x 0.03977 | boco_y 0.04024 | neumann_grad_t 0.39472 | pde 0.13398<p>Epoch 21/1000  | lr 7e-05 | initial 0.10485 | boco_x 0.04219 | boco_y 0.04339 | neumann_grad_t 0.36332 | pde 0.15055<p>Epoch 22/1000  | lr 7e-05 | initial 0.10004 | boco_x 0.03931 | boco_y 0.0402 | neumann_grad_t 0.31653 | pde 0.18681<p>Epoch 23/1000  | lr 8e-05 | initial 0.11384 | boco_x 0.04533 | boco_y 0.04651 | neumann_grad_t 0.34143 | pde 0.19803<p>Epoch 24/1000  | lr 8e-05 | initial 0.09738 | boco_x 0.03616 | boco_y 0.03555 | neumann_grad_t 0.27266 | pde 0.24228<p>Epoch 25/1000  | lr 9e-05 | initial 0.09597 | boco_x 0.03528 | boco_y 0.03341 | neumann_grad_t 0.24668 | pde 0.27253<p>Epoch 26/1000  | lr 9e-05 | initial 0.09385 | boco_x 0.03316 | boco_y 0.0312 | neumann_grad_t 0.22465 | pde 0.30622<p>Epoch 27/1000  | lr 0.0001 | initial 0.09623 | boco_x 0.03453 | boco_y 0.03295 | neumann_grad_t 0.22287 | pde 0.32429<p>Epoch 28/1000  | lr 0.0001 | initial 0.08608 | boco_x 0.02873 | boco_y 0.02686 | neumann_grad_t 0.18257 | pde 0.37163<p>Epoch 29/1000  | lr 0.00011 | initial 0.08114 | boco_x 0.02755 | boco_y 0.02623 | neumann_grad_t 0.15971 | pde 0.39039<p>Epoch 30/1000  | lr 0.00011 | initial 0.07812 | boco_x 0.02668 | boco_y 0.02579 | neumann_grad_t 0.13668 | pde 0.42185<p>Epoch 31/1000  | lr 0.00012 | initial 0.06921 | boco_x 0.02216 | boco_y 0.02224 | neumann_grad_t 0.10424 | pde 0.45979<p>Epoch 32/1000  | lr 0.00013 | initial 0.06987 | boco_x 0.02227 | boco_y 0.02311 | neumann_grad_t 0.09419 | pde 0.44834<p>Epoch 33/1000  | lr 0.00013 | initial 0.06555 | boco_x 0.01964 | boco_y 0.02122 | neumann_grad_t 0.0779 | pde 0.44451<p>Epoch 34/1000  | lr 0.00014 | initial 0.07136 | boco_x 0.02307 | boco_y 0.02492 | ...
# CPU times: user 3h 8min 53s, sys: 2min 14s, total: 3h 11min 8s
# Wall time: 3h 15min 45s

# %%
# evaluate
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

x = np.linspace(0,1,100)
y = np.linspace(0,1,100)
t = np.array([0,0.2,0.4,0.6,0.8,1])
c = np.array([1e-4,1e-3,1e-2,1e-1,1])
c1 = np.array([1,0.5,0.1])

for cc in c1:
    for t1 in t:

        eval_mesh=Mesh({'x': x, 'y': y, 't': t1, 'c': cc}, device=device)

        u=pde.eval(eval_mesh)
        u=u.cpu().numpy()

        _x, _y=np.meshgrid(x,y)
        u0=np.sin(np.pi*_x)*np.sin(np.pi*_y)*(np.cos(cc*np.sqrt(2)*np.pi*t1)+
                                              np.sin(cc*np.sqrt(2)*np.pi*t1))

        fig=plt.figure(figsize=(15, 5))
        ax1=fig.add_subplot(1,2,1,projection='3d')
        ax2=fig.add_subplot(1,2,2,projection='3d')
        ax1.plot_surface(_x, _y, u0.reshape((len(_y),len(_x))), cmap=cm.coolwarm, 
                         linewidth=0, antialiased=False)
        ax1.title.set_text('exact, c = %f, t = %f' %(cc, t1))
        ax2.plot_surface(_x, _y, u.reshape((len(_y),len(_x))), cmap=cm.coolwarm, 
                         linewidth=0, antialiased=False)
        ax2.title.set_text('predicted, c = %f, t = %f' %(cc, t1))
        plt.show()
        print("L2 error: ", np.sqrt(sum((u0.ravel()-u.ravel())**2))
      /np.sqrt(sum(u0.ravel()**2))*100,"%")
# Out:
# L2 error:  0.0982927448107928 %
# L2 error:  0.0590367264063758 %
# L2 error:  0.16698379693286253 %
# L2 error:  0.3736126272666393 %
# L2 error:  0.15276093185685868 %
# L2 error:  0.25262112662403724 %
# L2 error:  0.10818072597107081 %
# L2 error:  0.043467055567456565 %
# L2 error:  0.05873030047268685 %
# L2 error:  0.09568222030147504 %
# L2 error:  0.20004114926560945 %
# L2 error:  1.1424991642700233 %
# L2 error:  1.0235232426523884 %
# L2 error:  1.1247283652652809 %
# L2 error:  1.9364997720113746 %
# L2 error:  2.7649086043765223 %
# L2 error:  3.7313447140381246 %
# L2 error:  5.11882993406147 %
